# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
data = pd.read_csv('zomatoData.csv')
data_copy = data.copy()

# %%
data
# Out:
#                          Name  \
# 0                   Pizza Hut
# 1                   RollsKing
# 2             Punjabi Angithi
# 3               Chicago Pizza
# 4           BOX8 - Desi Meals
# ..                        ...
# 196               Hira Sweets
# 197                    Sandoz
# 198      Sita Ram Diwan Chand
# 199              Swagat Dhaba
# 200  Nukkad Ramji Samosa Wala
#
#                                                Address         Phone  Rating  \
# 0     17 & 18, Corner Market, Malviya Nagar, New Delhi  918929647587     3.7
# 1             Shop 2, 10/127, Malviya Nagar, New Delhi  919560101636     3.9
# 2    84, Ground Floor, Left Corner, Behind Hero Sho...  911149952492     4.0
# 3                    8-A, Hauz Khas Village, New Delhi  919540937301     3.7
# 4    F5, Ground Floor, Gautam Nagar, Gulmohar Park ...  918068172526     4.3
# ..                                                 ...           ...     ...
# 196                K 19/21, Connaught Place, New Delhi  919136587253     4.2
# 197      L-9, Ground Floor, Connaught Place, New Delhi  918595951359     4.2
# 198  2243, Chuna Mandi, Raj Guru Road, Paharganj, N...  911123587380     4.1
# 199            5137, Main Bazaar, Paharganj, New Delhi  918929734255     4.1
# 200  2E/6, Moti Bhavan, Near Jhandewalan Metro Stat...  919899105636     3.9
#
#      AvgCost                                          Known For  \
# 0        800  Casual Seating Area|Prompt Service|Reasonable ...
# 1        300  Pocket Friendly|Tasty|Contactless Delivery|Bes...
# 2        200  Fast Delivery Service|Cute Packaging|Food Pres...
# 3        700  Comforting Atmosphere|Spill Proof Packaging|Fr...
# 4        250  Customizable Food|Good Taste|Elaborate Menu|Fr...
# ..       ...                                                ...
# 196      500  South Indian Menu|Nice/Colourful Packaging|Par...
# 197      800  Good Staffs|Seating Inside|Quantity of Portion...
# 198        0  Paneer Bhatura|Meethi Lassi|Chana Kulcha|Chola...
# 199      300  Wonderful Presentation|Proper Packaging|Timely...
# 200       50                                                NaN
#
#                                         Popular Dishes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                   Chilly Momo|Veg Noodles|Dal|Momos|
# 3     Paneer Delight Pizza|Chicago Pizza|Pizzas|Drink|
# 4                                                  NaN
# ..                                                 ...
# 196  Paneer Dhokla|Kalakand|Deluxe Thali|Rasgulla|R...
# 197  Fruit Punch Mocktail|Bhatti Chicken|Handi Chic...
# 198                          Legendary choley bhature|
# 199                                                NaN
# 200                                                NaN
#
#                                                Cuisine  \
# 0            Pizza|Fast Food|Pasta|Beverages|Desserts|
# 1              Rolls|Fast Food|North Indian|Beverages|
# 2    North Indian|Chinese|Rolls|Momos|Street Food|P...
# 3                                     Pizza|Fast Food|
# 4                       North Indian|Biryani|Desserts|
# ..                                                 ...
# 196  Mithai|North Indian|South Indian|Chinese|Stree...
# 197  North Indian|Chinese|Fast Food|Mughlai|Rolls|C...
# 198                                      North Indian|
# 199                                      North Indian|
# 200                  Chinese|Street Food|North Indian|
#
#                                                Reviews       Location
# 0    Dining|Delivery|Casual Seating Area|Prompt Ser...    South Delhi
# 1    Dining|Delivery|Pocket Friendly|Tasty|Contactl...    South Delhi
# 2    Chilly Momo|Veg Noodles|Dal|Momos|Fast Deliver...    South Delhi
# 3    Dining|Delivery|Paneer Delight Pizza|Chicago P...    South Delhi
# 4    Customizable Food|Good Taste|Elaborate Menu|Fr...    South Delhi
# ..                                                 ...            ...
# 196  Dining|Delivery|Paneer Dhokla|Kalakand|Deluxe ...  Central Delhi
# 197  Dining|Delivery|Fruit Punch Mocktail|Bhatti Ch...  Central Delhi
# 198  Dining|Delivery|Paneer Bhatura|Meethi Lassi|Ch...  Central Delhi
# 199  Dining|Delivery|Wonderful Presentation|Proper ...  Central Delhi
# 200                                                NaN  Central Delhi
#
# [201 rows x 10 columns]

# %%
data.isna().sum()
# Out:
# Name               0
# Address            0
# Phone              0
# Rating             0
# AvgCost            0
# Known For         40
# Popular Dishes    94
# Cuisine           26
# Reviews           23
# Location           0
# dtype: int64

# %%
data.shape
# Out:
# (201, 10)

# %%
sclaer = MinMaxScaler()
data['AvgCost'] = sclaer.fit_transform(data[['AvgCost']])
data['Rating'] = sclaer.fit_transform(data[['Rating']])

# %%
wcss = []
cluster = []

for i in range(2, 15):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(data[['Rating', 'AvgCost']])
    wcss.append(kmeans.inertia_)
    cluster.append(i)

# %%
plt.plot(cluster, wcss)

# %%
kmeans = KMeans(n_clusters=6, random_state=0).fit(data.loc[:, ['AvgCost', 'Rating']])

# %%
data['clusters'] = kmeans.labels_
data_copy['clusters'] = kmeans.labels_

# %%
sns.scatterplot(data=data, x='Rating', y='AvgCost', hue='clusters')
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='AvgCost'>

# %%
d = {0: 'High Rating and Medium Cost', 1: 'High Rating and Low Cost', 2: 'Low Rating and High Cost', 3: 'Low Rating and Low Cost', 4: 'High Rating and High Cost', 5: 'Low Rating and Medium Cost'}

# %%
data['cluster_description'] = data['clusters'].map(d)
data_copy['cluster_description'] = data_copy['clusters'].map(d)

# %%
data.fillna('None', inplace=True)
data_copy.fillna('None', inplace=True)

# %%
data_copy.to_csv('updated_data.csv', index=False)

# %%
data_copy
# Out:
#                          Name  \
# 0                   Pizza Hut
# 1                   RollsKing
# 2             Punjabi Angithi
# 3               Chicago Pizza
# 4           BOX8 - Desi Meals
# ..                        ...
# 196               Hira Sweets
# 197                    Sandoz
# 198      Sita Ram Diwan Chand
# 199              Swagat Dhaba
# 200  Nukkad Ramji Samosa Wala
#
#                                                Address         Phone  Rating  \
# 0     17 & 18, Corner Market, Malviya Nagar, New Delhi  918929647587     3.7
# 1             Shop 2, 10/127, Malviya Nagar, New Delhi  919560101636     3.9
# 2    84, Ground Floor, Left Corner, Behind Hero Sho...  911149952492     4.0
# 3                    8-A, Hauz Khas Village, New Delhi  919540937301     3.7
# 4    F5, Ground Floor, Gautam Nagar, Gulmohar Park ...  918068172526     4.3
# ..                                                 ...           ...     ...
# 196                K 19/21, Connaught Place, New Delhi  919136587253     4.2
# 197      L-9, Ground Floor, Connaught Place, New Delhi  918595951359     4.2
# 198  2243, Chuna Mandi, Raj Guru Road, Paharganj, N...  911123587380     4.1
# 199            5137, Main Bazaar, Paharganj, New Delhi  918929734255     4.1
# 200  2E/6, Moti Bhavan, Near Jhandewalan Metro Stat...  919899105636     3.9
#
#      AvgCost                                          Known For  \
# 0        800  Casual Seating Area|Prompt Service|Reasonable ...
# 1        300  Pocket Friendly|Tasty|Contactless Delivery|Bes...
# 2        200  Fast Delivery Service|Cute Packaging|Food Pres...
# 3        700  Comforting Atmosphere|Spill Proof Packaging|Fr...
# 4        250  Customizable Food|Good Taste|Elaborate Menu|Fr...
# ..       ...                                                ...
# 196      500  South Indian Menu|Nice/Colourful Packaging|Par...
# 197      800  Good Staffs|Seating Inside|Quantity of Portion...
# 198        0  Paneer Bhatura|Meethi Lassi|Chana Kulcha|Chola...
# 199      300  Wonderful Presentation|Proper Packaging|Timely...
# 200       50                                               None
#
#                                         Popular Dishes  \
# 0                                                 None
# 1                                                 None
# 2                   Chilly Momo|Veg Noodles|Dal|Momos|
# 3     Paneer Delight Pizza|Chicago Pizza|Pizzas|Drink|
# 4                                                 None
# ..                                                 ...
# 196  Paneer Dhokla|Kalakand|Deluxe Thali|Rasgulla|R...
# 197  Fruit Punch Mocktail|Bhatti Chicken|Handi Chic...
# 198                          Legendary choley bhature|
# 199                                               None
# 200                                               None
#
#                                                Cuisine  \
# 0            Pizza|Fast Food|Pasta|Beverages|Desserts|
# 1              Rolls|Fast Food|North Indian|Beverages|
# 2    North Indian|Chinese|Rolls|Momos|Street Food|P...
# 3                                     Pizza|Fast Food|
# 4                       North Indian|Biryani|Desserts|
# ..                                                 ...
# 196  Mithai|North Indian|South Indian|Chinese|Stree...
# 197  North Indian|Chinese|Fast Food|Mughlai|Rolls|C...
# 198                                      North Indian|
# 199                                      North Indian|
# 200                  Chinese|Street Food|North Indian|
#
#                                                Reviews       Location  \
# 0    Dining|Delivery|Casual Seating Area|Prompt Ser...    South Delhi
# 1    Dining|Delivery|Pocket Friendly|Tasty|Contactl...    South Delhi
# 2    Chilly Momo|Veg Noodles|Dal|Momos|Fast Deliver...    South Delhi
# 3    Dining|Delivery|Paneer Delight Pizza|Chicago P...    South Delhi
# 4    Customizable Food|Good Taste|Elaborate Menu|Fr...    South Delhi
# ..                                                 ...            ...
# 196  Dining|Delivery|Paneer Dhokla|Kalakand|Deluxe ...  Central Delhi
# 197  Dining|Delivery|Fruit Punch Mocktail|Bhatti Ch...  Central Delhi
# 198  Dining|Delivery|Paneer Bhatura|Meethi Lassi|Ch...  Central Delhi
# 199  Dining|Delivery|Wonderful Presentation|Proper ...  Central Delhi
# 200                                               None  Central Delhi
#
#      clusters          cluster_description
# 0           2     Low Rating and High Cost
# 1           5   Low Rating and Medium Cost
# 2           3      Low Rating and Low Cost
# 3           2     Low Rating and High Cost
# 4           1     High Rating and Low Cost
# ..        ...                          ...
# 196         0  High Rating and Medium Cost
# 197         4    High Rating and High Cost
# 198         1     High Rating and Low Cost
# 199         0  High Rating and Medium Cost
# 200         3      Low Rating and Low Cost
#
# [201 rows x 12 columns]
