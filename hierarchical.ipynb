# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering 
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('updated_data.csv')
scaler = MinMaxScaler()
data['Rating'] = scaler.fit_transform(data['Rating'].values.reshape(-1,1))
data['AvgCost'] = scaler.fit_transform(data['AvgCost'].values.reshape(-1,1))

# %% [markdown]
# ##### Single Linkage

# %%
plt.figure(figsize = (10, 7))
dendogram_1 = sch.dendrogram(sch.linkage(data.loc[:, ['AvgCost', 'Rating']], method = 'single', metric = 'euclidean'))

# %%
ac = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage ='single')
y_1 = ac.fit_predict(data.loc[:, ['AvgCost', 'Rating']])

# %%
print('Silhouette Score: {}, Davies Bouldin Score: {}'.format(silhouette_score(data.loc[:, ['AvgCost', 'Rating']], y_1), davies_bouldin_score(data.loc[:, ['AvgCost', 'Rating']], y_1)))
# Out:
# Silhouette Score: 0.3667815190603485, Davies Bouldin Score: 0.41437205627621765

# %%
sns.scatterplot(x  ='Rating', y = 'AvgCost', data = data,  hue = y_1, palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='AvgCost'>

# %% [markdown]
# ##### Complete Linkage

# %%
plt.figure(figsize = (10, 7))
dendogram_2 = sch.dendrogram(sch.linkage(data.loc[:, ['AvgCost', 'Rating']], method = 'complete', metric = 'euclidean'))

# %%
ac = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage ='complete')
y_2 = ac.fit_predict(data.loc[:, ['AvgCost', 'Rating']])

# %%
print('Silhouette Score: {}, Davies Bouldin Score: {}'.format(silhouette_score(data.loc[:, ['AvgCost', 'Rating']], y_2), davies_bouldin_score(data.loc[:, ['AvgCost', 'Rating']], y_2)))
# Out:
# Silhouette Score: 0.29660803535416785, Davies Bouldin Score: 0.8730661880903113

# %%
sns.scatterplot(x  ='Rating', y = 'AvgCost', data = data,  hue = y_2, palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='AvgCost'>

# %% [markdown]
# ##### Group Average Linkage

# %%
plt.figure(figsize = (10, 7))
dendogram_3 = sch.dendrogram(sch.linkage(data.loc[:, ['AvgCost', 'Rating']], method = 'average', metric = 'euclidean'))

# %%
ac = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage ='average')
y_3 = ac.fit_predict(data.loc[:, ['AvgCost', 'Rating']])

# %%
print('Silhouette Score: {}, Davies Bouldin Score: {}'.format(silhouette_score(data.loc[:, ['AvgCost', 'Rating']], y_3), davies_bouldin_score(data.loc[:, ['AvgCost', 'Rating']], y_3)))
# Out:
# Silhouette Score: 0.32298768836930586, Davies Bouldin Score: 0.8619263460964103

# %%
sns.scatterplot(x  ='Rating', y = 'AvgCost', data = data,  hue = y_3, palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='AvgCost'>

# %% [markdown]
# ##### Minimum variance linkage

# %%
plt.figure(figsize = (10, 7))
dendogram_4 = sch.dendrogram(sch.linkage(data.loc[:, ['AvgCost', 'Rating']], method = 'ward', metric = 'euclidean'))

# %%
ac = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage ='ward')
y_4 = ac.fit_predict(data.loc[:, ['AvgCost', 'Rating']])

# %%
print('Silhouette Score: {}, Davies Bouldin Score: {}'.format(silhouette_score(data.loc[:, ['AvgCost', 'Rating']], y_4), davies_bouldin_score(data.loc[:, ['AvgCost', 'Rating']], y_4)))
# Out:
# Silhouette Score: 0.37610633696137064, Davies Bouldin Score: 0.8690073190283922

# %%
sns.scatterplot(x  ='Rating', y = 'AvgCost', data = data,  hue = y_4, palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='AvgCost'>
